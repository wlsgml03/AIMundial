# %%
import pandas as pd

# %%
corn = pd.read_csv("corn-yield-gap.csv")
rice = pd.read_csv("rice-yield-gap.csv")
xtr_poverty = pd.read_csv("share-of-population-living-in-extreme-poverty.csv")
#healthy_diet = pd.read_csv("share-of-population-that-cannot-afford-a-healthy-diet.csv")
calories_per_person = pd.read_csv("total-daily-supply-of-calories-per-person.csv")
#health_care_spend = pd.read_csv("total-healthcare-spending-as-a-share-of-gdp.csv")
trade_as_gdp_share = pd.read_csv("trade-as-share-of-gdp.csv")
wheat = pd.read_csv("wheat-yield-gap.csv")
allocations = pd.read_csv("allocations_combined.csv")

# %%
wheat.head()
# Out:
#         Entity Code  Year  Wheat yield gap
# 0  Afghanistan  AFG  1961           2.9780
# 1  Afghanistan  AFG  1962           3.0265
# 2  Afghanistan  AFG  1963           3.1683
# 3  Afghanistan  AFG  1964           3.0490
# 4  Afghanistan  AFG  1965           3.0277

# %%
wheat.Year.unique()
# Out:
# array([1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 1850, 1911, 1934,
#        1950, 1275, 1305, 1355, 1405, 1455, 1555, 1605, 1655, 1705, 1755,
#        1805, 1855, 1865, 1887, 1912, 1932, 1944])

# %%
corn.Year.unique()
# Out:
# array([1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 1866, 1867, 1868,
#        1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879,
#        1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890,
#        1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901,
#        1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912,
#        1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923,
#        1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934,
#        1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945,
# ...

# %%
corn.head()
# Out:
#         Entity Code  Year  Corn yield gap
# 0  Afghanistan  AFG  1961        9.000000
# 1  Afghanistan  AFG  1962        9.000000
# 2  Afghanistan  AFG  1963        8.973999
# 3  Afghanistan  AFG  1964        8.974299
# 4  Afghanistan  AFG  1965        8.959999

# %%
rice.Year.unique()
# Out:
# array([1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023])

# %%
rice.head()
# Out:
#         Entity Code  Year  Rice yield gap
# 0  Afghanistan  AFG  1961          7.8410
# 1  Afghanistan  AFG  1962          7.8410
# 2  Afghanistan  AFG  1963          7.8410
# 3  Afghanistan  AFG  1964          7.6327
# 4  Afghanistan  AFG  1965          7.6327

# %%
xtr_poverty.Year.unique()
# Out:
# array([1996, 2002, 2005, 2008, 2012, 2014, 2015, 2016, 2017, 2018, 2019,
#        2020, 1988, 1995, 2011, 2000, 1980, 1986, 1987, 1991, 1992, 1993,
#        1994, 1997, 1998, 1999, 2001, 2003, 2004, 2006, 2007, 2009, 2010,
#        2013, 2021, 2022, 2023, 2024, 1981, 1985, 1989, 1983, 1990, 1982,
#        1984, 1971, 1973, 1975, 1977, 1979, 2025, 1970, 1978, 1968, 1969,
#        1972, 1974, 1976, 1963, 1964, 1965, 1966, 1967])

# %%
xtr_poverty.head()
xtr_poverty = xtr_poverty.rename(columns={'Country': 'Entity', 'Year': 'Year', 'Share below $3 a day':'Share below $3 a day'})
xtr_poverty.head()
# Out:
#     Entity  Year  Share below $3 a day
# 0  Albania  1996              2.967841
# 1  Albania  2002              4.194722
# 2  Albania  2005              2.650218
# 3  Albania  2008              0.827308
# 4  Albania  2012              1.794590

# %%
healthy_diet.Year.unique()
# Out:
# array([2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024])

# %%
calories_per_person.Year.unique()
# Out:
# array([1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018, 2019, 2020, 2021, 2022])

# %%
calories_per_person.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1961
# 1  Afghanistan  AFG  1962
# 2  Afghanistan  AFG  1963
# 3  Afghanistan  AFG  1964
# 4  Afghanistan  AFG  1965
#
#    All food - Food available for consumption (kilocalories per day per capita)
# 0                                          2914.3484
# 1                                          2835.6074
# 2                                          2623.7017
# 3                                          2872.5679
# 4                                          2876.1790

# %%
health_care_spend.Year.unique()
# Out:
# array([2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2000,
#        2001])

# %%
trade_as_gdp_share.Year.unique()
# Out:
# array([2020, 2021, 2022, 2023, 1980, 1981, 1982, 1983, 1984, 1985, 1986,
#        1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997,
#        1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#        2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019,
#        2024, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969,
#        1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979])

# %%
trade_as_gdp_share.head()
# Out:
#         Entity Code  Year  Trade (% of GDP)
# 0  Afghanistan  AFG  2020         46.709896
# 1  Afghanistan  AFG  2021         51.411716
# 2  Afghanistan  AFG  2022         72.885470
# 3  Afghanistan  AFG  2023         67.584660
# 4      Albania  ALB  1980         47.494090

# %%
allocations = allocations.rename(columns={'countryName': 'Entity', 'year': 'Year', 'totalAmountApproved':'Allocations'})
allocations.head()
# Out:
#         Entity  Year  Allocations
# 0  Afghanistan  2016    3312409.0
# 1  Afghanistan  2017    4600042.0
# 2  Afghanistan  2018    8362704.0
# 3  Afghanistan  2019     422360.0
# 4  Afghanistan  2020   21625000.0

# %%
df1 = pd.merge(wheat,corn, how='inner')
df2 = pd.merge(df1,rice, how='inner')
df3 = pd.merge(df2,xtr_poverty, how='inner')
##df4 = pd.merge(df3,healthy_diet, how='inner')
df5 = pd.merge(df3,calories_per_person, how='inner')
##df6 = pd.merge(df5,health_care_spend, how='inner')
df7 = pd.merge(df5,trade_as_gdp_share, how='inner')
df8 = pd.merge(df7,wheat, how='inner')
df9 = pd.merge(df8,allocations, how='left')

# %%
df9.head()
# Out:
#     Entity Code  Year  Wheat yield gap  Corn yield gap  Rice yield gap  \
# 0  Algeria  DZA  1988           3.6894       10.810000        6.567500
# 1  Algeria  DZA  1995           3.3976       10.198501        7.398499
# 2  Algeria  DZA  2011           2.5495        9.472601        7.751100
# 3   Angola  AGO  2008           3.2000        4.915400        5.751600
# 4   Angola  AGO  2018           3.2847        4.662300        5.107700
#
#    Share below $3 a day  \
# 0             12.263001
# 1             11.807000
# 2              0.000000
# 3             22.079582
# 4             39.294704
#
#    All food - Food available for consumption (kilocalories per day per capita)  \
# 0                                          2784.9510
# 1                                          2867.6404
# 2                                          3316.9983
# 3                                          1905.3518
# 4                                          2450.5085
#
#    Trade (% of GDP)  Allocations
# ...

# %%
df9.Year.unique()
# Out:
# array([1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973,
#        1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984,
#        1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995,
#        1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
#        2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017,
#        2018, 2019, 2020, 2021, 2022])

# %%
df9[df9['Allocations'].isnull()]
# Out:
#         Entity Code  Year  Wheat yield gap  Corn yield gap  Rice yield gap  \
# 0      Algeria  DZA  1988           3.6894       10.810000        6.567500
# 1      Algeria  DZA  1995           3.3976       10.198501        7.398499
# 2      Algeria  DZA  2011           2.5495        9.472601        7.751100
# 3       Angola  AGO  2008           3.2000        4.915400        5.751600
# 5    Australia  AUS  1981           2.4135        4.141600        2.210200
# ..         ...  ...   ...              ...             ...             ...
# 909     Zambia  ZMB  2010           0.0000        2.632900        5.702200
# 910     Zambia  ZMB  2015           0.0000        2.189000        5.955200
# 911     Zambia  ZMB  2022           0.0000        2.793900        5.806500
# 912   Zimbabwe  ZWE  2011           1.9896        4.403200        7.670300
# 913   Zimbabwe  ZWE  2017           2.8958        3.666700        7.845500
#
#      Share below $3 a day  \
# 0               12.263001
# ...

# %%
df9['binary'] = df9['Allocations'].apply(lambda x: 1 if pd.notna(x) else 0)

# %%
df9.head(1)
# Out:
#     Entity Code  Year  Wheat yield gap  Corn yield gap  Rice yield gap  \
# 0  Algeria  DZA  1988           3.6894           10.81          6.5675
#
#    Share below $3 a day  \
# 0             12.263001
#
#    All food - Food available for consumption (kilocalories per day per capita)  \
# 0                                           2784.951
#
#    Trade (% of GDP)  Allocations  binary
# 0         38.111588          NaN       0

# %%
df8.to_csv("indicators.csv")

# %%
df1.size
# Out:
# 24685

# %%
df2.size
# Out:
# 22140

# %%
df3.size
# Out:
# 6860

# %%
df5.size
# Out:
# 7592

# %%
df7.size
# Out:
# 8235

# %%
df8.size
# Out:
# 8235

# %%
df9.size
# Out:
# 9150

# %%
df9.head(1)
# Out:
#     Entity Code  Year  Wheat yield gap  Corn yield gap  Rice yield gap  \
# 0  Algeria  DZA  1988           3.6894           10.81          6.5675
#
#    Share below $3 a day  \
# 0             12.263001
#
#    All food - Food available for consumption (kilocalories per day per capita)  \
# 0                                           2784.951
#
#    Trade (% of GDP)  Allocations  binary
# 0         38.111588          NaN       0

# %%
df = df9.rename(columns={'Entity': 'entity',
                        'Code': 'code',
                        'Year':'year',
                        'Wheat yield gap': 'wheat_yield_gap',
                        'Corn yield gap':'corn_yield_gap',
                        'Rice yield gap': 'rice_yield_gap',
                        'Share below $3 a day':'share_below_3_daily',
                        'All food - Food available for consumption (kilocalories per day per capita)':'kilo_cals_consumed_daily',
                        'Trade (% of GDP)': 'trade_of_gdp',
                        'Allocations':'allocations',
                        'binary':'binary'
                       })

# %%
df.head()
# Out:
#     entity code  year  wheat_yield_gap  corn_yield_gap  rice_yield_gap  \
# 0  Algeria  DZA  1988           3.6894       10.810000        6.567500
# 1  Algeria  DZA  1995           3.3976       10.198501        7.398499
# 2  Algeria  DZA  2011           2.5495        9.472601        7.751100
# 3   Angola  AGO  2008           3.2000        4.915400        5.751600
# 4   Angola  AGO  2018           3.2847        4.662300        5.107700
#
#    share_below_3_daily  kilo_cals_consumed_daily  trade_of_gdp  allocations  \
# 0            12.263001                 2784.9510     38.111588          NaN
# 1            11.807000                 2867.6404     55.191006          NaN
# 2             0.000000                 3316.9983     62.220090          NaN
# 3            22.079582                 1905.3518    108.680410          NaN
# 4            39.294704                 2450.5085     58.916480     900003.0
#
#    binary
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1

# %%
df.to_csv("indicators3.csv")

# %%
famine_score = pd.read_csv("famine_risk_scores.csv")

# %%
famine_score.size
# Out:
# 23188

# %%
famine_score.head(20)
# Out:
#         entity code  year  wheat_yield_gap  corn_yield_gap  rice_yield_gap  \
# 0    Venezuela  VEN  1992           4.2435        1.624000        1.050000
# 1     Pakistan  PAK  1998           2.5224        2.374700        2.737000
# 2     Pakistan  PAK  2005           2.1742        1.175700        2.455800
# 3   Tajikistan  TJK  2021           1.9990        0.000000        0.000000
# 4       Uganda  UGA  2019           2.4487        3.047400        5.606500
# 5     Tanzania  TZA  2011           3.5296        3.459700        4.731400
# 6      Ecuador  ECU  2004           4.6947        3.315900        1.671299
# 7   Mozambique  MOZ  2019           3.0650        3.106900        4.833600
# 8      Ecuador  ECU  2018           3.7858        1.575500        2.258399
# 9   Madagascar  MDG  2005           1.9306        3.473600        3.376000
# 10      Brazil  BRA  1987           2.2346        3.075700        4.212500
# ...

# %%
famine_score[famine_score['predicted_famine'] == 1]
# Out:
#          entity code  year  wheat_yield_gap  corn_yield_gap  rice_yield_gap  \
# 0     Venezuela  VEN  1992           4.2435        1.624000        1.050000
# 1      Pakistan  PAK  1998           2.5224        2.374700        2.737000
# 2      Pakistan  PAK  2005           2.1742        1.175700        2.455800
# 3    Tajikistan  TJK  2021           1.9990        0.000000        0.000000
# 4        Uganda  UGA  2019           2.4487        3.047400        5.606500
# ..          ...  ...   ...              ...             ...             ...
# 271       Italy  ITA  2010           1.8079        0.632799        3.118100
# 272        Peru  PER  2007           4.5638        4.802899        0.678299
# 273     Bolivia  BOL  2016           2.8766        3.132900        3.077100
# 274        Peru  PER  2019           4.2577        4.155600        0.000000
# 275    Honduras  HND  2019           3.1038        2.536100        2.323200
#
# ...

# %%
famine_score[famine_score['predicted_famine'] == 0]
# Out:
#          entity      code  year  wheat_yield_gap  corn_yield_gap  \
# 276     Romania       ROU  2006           2.7863          6.2546
# 277        Peru       PER  2012           4.3309          4.3316
# 278    Paraguay       PRY  2022           2.4039          1.2911
# 279  Tajikistan       TJK  2022           2.0630          0.0000
# 280       World  OWID_WRL  2004           1.6974          2.4449
# ..          ...       ...   ...              ...             ...
# 743      Mexico       MEX  2020           0.0000          2.3478
# 744  Azerbaijan       AZE  2005           2.0582          7.2297
# 745     Hungary       HUN  2005           1.3100          2.1029
# 746  Kazakhstan       KAZ  2006           1.6352          6.1283
# 747     Romania       ROU  2007           3.9500          8.1270
#
#      rice_yield_gap  share_below_3_daily  kilo_cals_consumed_daily  \
# 276        6.070700            11.075025                 3597.8281
# ...
